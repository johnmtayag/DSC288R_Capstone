# %%
import yaml

# %%
class_cols = ["Cardiomegaly", "Consolidation", "Edema", "Atelectasis", "Pleural Effusion"]
n_classes = len(class_cols)
n_class_values = 3

# %%
# Common variables used across notebooks
common_params = dict(
    class_cols = class_cols,
    conditions = class_cols,
    n_classes = n_classes,
    n_class_values = n_class_values
)

with open("config/common.yaml", "w") as param_file:
    yaml.dump(common_params, param_file, default_flow_style=True)

# %%
# Pipeline kwargs
pipeline_kwargs = dict(
    scale_min=0,
    scale_max=255,
    usm_sigma=10,
    usm_weight=1.2,
    he_sigma=5
)

with open("config/pipeline_kwargs.yaml", "w") as param_file:
    yaml.dump(pipeline_kwargs, param_file, default_flow_style=True)

# %%
# ResNet50, 224x224, RAW
param_name = "ResNet50_BASE224_RAW"

params = dict(
    model_type="ResNet50",
    dim=224,
    enhanced=False,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.001,
    lr2 = 0.000001
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
# ResNet50, 224x224, ENHANCED
param_name = "ResNet50_BASE224_ENHANCED"

params = dict(
    model_type="ResNet50",
    dim=224,
    enhanced=True,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.001,
    lr2 = 0.000001
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
# ResNet50, 384x384, RAW
param_name = "ResNet50_BASE384_RAW"

params = dict(
    model_type="ResNet50",
    dim=384,
    enhanced=False,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.0025,
    lr2 = 0.0000025
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
# ResNet50, 384x384, ENHANCED
param_name = "ResNet50_BASE384_ENHANCED"

params = dict(
    model_type="ResNet50",
    dim=384,
    enhanced=True,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.0025,
    lr2 = 0.0000025
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
# ResNet50, 512x512, RAW
param_name = "ResNet50_BASE512_RAW"

params = dict(
    model_type="ResNet50",
    dim=512,
    enhanced=False,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.0025,
    lr2 = 0.0000025
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
# ResNet50, 512x512, ENHANCED
param_name = "ResNet50_BASE512_ENHANCED"

params = dict(
    model_type="ResNet50",
    dim=512,
    enhanced=True,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.0025,
    lr2 = 0.0000025
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
# DenseNet121, 224x224, RAW
param_name = "DenseNet121_BASE224_RAW"

params = dict(
    model_type="DenseNet121",
    dim=224,
    enhanced=False,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.001,
    lr2 = 0.000001
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
# DenseNet121, 224x224, ENHANCED
param_name = "DenseNet121_BASE224_ENHANCED"

params = dict(
    model_type="DenseNet121",
    dim=224,
    enhanced=True,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.001,
    lr2 = 0.000001
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
# DenseNet121, 384x384, RAW
param_name = "DenseNet121_BASE384_RAW"

params = dict(
    model_type="DenseNet121",
    dim=384,
    enhanced=False,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.0025,
    lr2 = 0.0000025
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
# DenseNet121, 384x384, ENHANCED
param_name = "DenseNet121_BASE384_ENHANCED"

params = dict(
    model_type="DenseNet121",
    dim=384,
    enhanced=True,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.0025,
    lr2 = 0.0000025
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
# DenseNet121, 512x512, RAW
param_name = "DenseNet121_BASE512_RAW"

params = dict(
    model_type="DenseNet121",
    dim=512,
    enhanced=False,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.0025,
    lr2 = 0.0000001
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
# DenseNet121, 512x512, ENHANCED
param_name = "DenseNet121_BASE512_ENHANCED"

params = dict(
    model_type="DenseNet121",
    dim=512,
    enhanced=True,
    #
    min_epochs = 8,
    max_epochs = 50,
    freeze_all_but_final_layer = True,
    unfreeze_all_layers_at_epoch = 100, # No unfreezing of all layers if >= max_epochs
    update_learning_rate_at_epoch = 5,
    ep = 5e-4,
    use_weights = True,
    #
    lr1 = 0.0025,
    lr2 = 0.0000025
)

with open(f"config/{param_name}.yaml", "w") as param_file:
    yaml.dump(params, param_file, default_flow_style=True)

# %%
### Grad CAM: ResNet kwargs
wrapper_kwargs0 = dict(
    model_type="ResNet50", dim=224, enhanced=False
)
wrapper_kwargs1 = dict(
    model_type="ResNet50", dim=224, enhanced=True
)
wrapper_kwargs2 = dict(
    model_type="ResNet50", dim=384, enhanced=False
)
wrapper_kwargs3 = dict(
    model_type="ResNet50", dim=384, enhanced=True
)
wrapper_kwargs4 = dict(
    model_type="ResNet50", dim=512, enhanced=False
)
wrapper_kwargs5 = dict(
    model_type="ResNet50", dim=512, enhanced=True
)
### Grad CAM: DenseNet kwargs
wrapper_kwargs6 = dict(
    model_type="DenseNet121", dim=224, enhanced=False
)
wrapper_kwargs7 = dict(
    model_type="DenseNet121", dim=224, enhanced=True
)
wrapper_kwargs8 = dict(
    model_type="DenseNet121", dim=384, enhanced=False
)
wrapper_kwargs9 = dict(
    model_type="DenseNet121", dim=384, enhanced=True
)
wrapper_kwargs10 = dict(
    model_type="DenseNet121", dim=512, enhanced=False
)
wrapper_kwargs11 = dict(
    model_type="DenseNet121", dim=512, enhanced=True
)

wrapper_kwargs = dict(
    wrapper_kwargs0=wrapper_kwargs0,
    wrapper_kwargs1=wrapper_kwargs1,
    wrapper_kwargs2=wrapper_kwargs2,
    wrapper_kwargs3=wrapper_kwargs3,
    wrapper_kwargs4=wrapper_kwargs4,
    wrapper_kwargs5=wrapper_kwargs5,
    wrapper_kwargs6=wrapper_kwargs6,
    wrapper_kwargs7=wrapper_kwargs7,
    wrapper_kwargs8=wrapper_kwargs8,
    wrapper_kwargs9=wrapper_kwargs9,
    wrapper_kwargs10=wrapper_kwargs10,
    wrapper_kwargs11=wrapper_kwargs11
)
    
with open("config/wrapper_kwargs.yaml", "w") as param_file:
    yaml.dump(wrapper_kwargs, param_file, default_flow_style=False)
